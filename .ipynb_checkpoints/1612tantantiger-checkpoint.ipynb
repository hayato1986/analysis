# %%
#必要なライブラリを予めすべてインポート
import pandas as pd
import numpy as np
import pylab as pl
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
# %matplotlib inline
sns.set_style('whitegrid')

# %%
#CSVデータをDF形式で読み込み。 indexにdateを設定
rowdata = pd.read_csv('/Users/hayato1986/Documents/analysis/open/data/tantantigerdata.csv', 
                      parse_dates=['日付'],index_col=['日付'], dayfirst=True)
#rowdata['week'] = rowdata.index.weekday #曜日を追加

# %%
#データ概要1.
rowdata.sort_values(by='来客数', ascending=True).head(3)
# Out:
#              来客数     売上  単価平均  リピート数  新規合計  平均気温  最高気温  最低気温  降水量(mm)  日照時間  \
# 日付
#  9月 20 (火)    57  54300  1901     25    32  19.1  20.1  17.6     91.5   0.0
#  11月 21 (月)   57  55950  1981     29    28  12.6  14.7  10.2      2.5   0.0
#  10月 17 (月)   58  57450  1997     33    25  17.5  19.5  15.7     24.0   0.0
#
#              平均風速(m/s)  最大風速(m/s) 最大風速(m/s).1  平均蒸気圧(hPa)    天気昼   天気夜    曜日
# 日付
#  9月 20 (火)         3.0        6.2          北西        22.1     大雨  大雨後曇   火曜日
#  11月 21 (月)        2.3        4.5          北東        12.8  曇後時々雨  雨一時曇   月曜日
#  10月 17 (月)        1.9        5.9         南南東        19.0    雨後曇  曇時々雨   月曜日

# %%
#データ概要2
rowdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 77 entries,  9月 19 (月) to  12月 19 (月)
# Data columns (total 17 columns):
# 来客数            77 non-null int64
# 売上             77 non-null int64
# 単価平均           77 non-null int64
# リピート数          77 non-null int64
# 新規合計           77 non-null int64
# 平均気温           77 non-null float64
# 最高気温           77 non-null float64
# 最低気温           77 non-null float64
# 降水量(mm)        77 non-null float64
# 日照時間           77 non-null float64
# 平均風速(m/s)      77 non-null float64
# 最大風速(m/s)      77 non-null float64
# 最大風速(m/s).1    77 non-null object
# 平均蒸気圧(hPa)     77 non-null float64
# 天気昼            77 non-null object
# 天気夜            77 non-null object
# 曜日             77 non-null object
# dtypes: float64(8), int64(5), object(4)
# memory usage: 10.8+ KB

# %%
#データ概要3
rowdata.describe()
# Out:
#               来客数             売上        単価平均      リピート数       新規合計       平均気温  \
# count   77.000000      77.000000    77.00000  77.000000  77.000000  77.000000
# mean    82.922078   81094.805195  1962.25974  33.376623  49.545455  14.845455
# std     15.961934   16141.067239    37.60998   9.956536  16.360692   5.858362
# min     57.000000   54300.000000  1884.00000  14.000000  23.000000   2.800000
# 25%     72.000000   70100.000000  1940.00000  26.000000  37.000000  10.600000
# 50%     82.000000   81050.000000  1960.00000  33.000000  49.000000  13.600000
# 75%     91.000000   88700.000000  1990.00000  41.000000  60.000000  19.400000
# max    128.000000  126450.000000  2054.00000  56.000000  94.000000  26.500000
#
#             最高気温       最低気温    降水量(mm)      日照時間  平均風速(m/s)  最大風速(m/s)  \
# count  77.000000  77.000000  77.000000  77.00000  77.000000  77.000000
# mean   18.890909  11.419481   5.831169   4.30000   2.474026   5.293506
# std     5.865559   6.162771  14.710051   3.59184   0.705505   1.638142
# min     8.600000   0.300000   0.000000   0.00000   1.200000   3.000000
# 25%    14.600000   7.300000   0.000000   0.50000   1.900000   4.100000
# 50%    18.300000  10.000000   0.000000   3.90000   2.400000   4.700000
# 75%    22.900000  17.400000   2.500000   7.60000   3.000000   6.400000
# max    32.000000  24.000000  91.500000  10.00000   4.900000  10.300000
#
#        平均蒸気圧(hPa)
# count   77.000000
# mean    13.133766
# std      6.868264
# min      3.800000
# 25%      7.800000
# 50%     11.100000
# 75%     18.200000
# max     29.600000

# %% [markdown]
# ***
# # タンタンタイガーの下半期売上分析
# ## Objective(目的)＆Why (なぜやるのか)
# タンタンタイガーの下半期売上データに対する分析をする。
# 各データから意味を抽出して、売上に影響している要因を見つけ出し、改善アクションにつなげることを目的とする。
#
# ## Data for deep dive (見てみるデータ)
# 1. 時系列における売上の推移はどうなっているか
#  - 開店直後からの数値推移
#  - 新規顧客の推移
#  - リピーターの推移
#  - リピーターと曜日の相関
# 2. 天候による売上の相関関係はどうなっているか
#  - 気温と売上の相関
#  - 天気と売上の相関
# 3. 売上の回帰モデルはどうなっているか
#  - 重回帰式の作成と妥当性の検証

# %%
#1. 時系列における売上の推移はどうなっているか
rowdata['売上'].plot(legend=True, figsize=(16, 4))

# %%
#よくわからないので移動平均的で出す。
rowdata_rolling = rowdata.rolling(window=8, min_periods=8).mean() #8日の移動平均
rowdata_rolling['売上'].plot(legend=True, figsize=(16, 4))

# %%
rowdata_rolling.loc[:,['リピート数','新規合計']].plot(
    legend=True, figsize=(16, 8), y=['リピート数','新規合計']
          , kind='area', stacked=True, alpha=0.5
)

# %% [markdown]
# - リピーター数は伸びている
# - 新規は10月22日のTVCMで大きく増えたが少し右肩下がり
# - リピーター数が伸びているので新規の落ち込みをカバーしている。全体では減ってない

# %% [markdown]
# # 2. 天候による売上の相関関係はどうなっているか

# %%
#とりあえず変数すべてで相関のヒートマップを見てみよう
fig, ax = plt.subplots(figsize=(20,20)) #Sizeを定義する
sns.heatmap(rowdata.corr() ,annot=True, linewidths=.5, ax=ax)

# %%
#よくわからないので相関がないところを削除していく。
fig, ax = plt.subplots(figsize=(10,10)) #Sizeを定義する
data = rowdata.drop(['week','最大風速(m/s).1','平均雲量(10分比)','平均蒸気圧(hPa)','最高気温(℃)','最低気温(℃)','最大風速(m/s)','売上 の SUM'], axis=1)
sns.heatmap(data.corr() ,annot=True, linewidths=.5, ax=ax)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-147-dec519df538e> in <module>()
#       1 #よくわからないので相関がないところを削除していく。
#       2 fig, ax = plt.subplots(figsize=(10,10)) #Sizeを定義する
# ----> 3 data = rowdata.drop(['week','最大風速(m/s).1','平均雲量(10分比)','平均蒸気圧(hPa)','最高気温(℃)','最低気温(℃)','最大風速(m/s)','売上 の SUM'], axis=1)
#       4 sns.heatmap(data.corr() ,annot=True, linewidths=.5, ax=ax)
#
# /Users/hayato1986/.pyenv/versions/anaconda3-4.0.0/lib/python3.5/site-packages/pandas/core/generic.py in drop(self, labels, axis, level, inplace, errors)
#    1871                 new_axis = axis.drop(labels, level=level, errors=errors)
#    1872             else:
# -> 1873                 new_axis = axis.drop(labels, errors=errors)
#    1874             dropped = self.reindex(**{axis_name: new_axis})
#    1875             try:
#
# /Users/hayato1986/.pyenv/versions/anaconda3-4.0.0/lib/python3.5/site-packages/pandas/indexes/base.py in drop(self, labels, errors)
#    2964             if errors != 'ignore':
#    2965                 raise ValueError('labels %s not contained in axis' %
# -> 2966                                  labels[mask])
#    2967             indexer = indexer[~mask]
#    2968         return self.delete(indexer)
#
# ValueError: labels ['week' '平均雲量(10分比)' '最高気温(℃)' '最低気温(℃)' '売上 の SUM'] not contained in axis

# %% [markdown]
# - リピート数と単価平均に相関が見られそう
# - 平均気温とリピート数に負の相関があるかも。逆に新規には正の相関？
# - 雨と来店数はあんまり関係なさそう
# - 風はすべての数値にほとんど関係ない
# - 来客数は新規の数で決まることが多そう

# %%
#気温と売上の相関を詳しく見てみる　=> 来客数 の SUMと平均気温(℃)
#sns.jointplot('平均気温(℃)', '来客数 の SUM', data=rowdata, kind="scatter")
rowdata.sort_values(by='来客数 の SUM', ascending=True)
# Out:
#             来客数 の SUM  売上 の SUM  単価 の AVERAGE  リピート数 の SUM  新規のSUM  平均気温(℃)  \
# 日付
# 2016-12-02         28     26600    950.000000           14      14     11.5
# 2016-12-05         49     46950    958.163265           23      26     12.7
# 2016-09-26         52     49550    952.884615           20      32     25.4
# 2016-10-11         53     49700    937.735849           13      40     17.6
# 2016-09-30         53     49750    938.679245           20      33     21.4
# 2016-09-20         57     54300    950.539867           25      32     19.1
# 2016-11-21         57     55950    990.405405           29      28     12.6
# 2016-11-24         58     56600    972.969697           28      30      2.8
# 2016-10-17         58     57450    998.547980           33      25     17.5
# 2016-11-10         59     57350    976.000000           35      24      9.6
# 2016-11-14         59     58350    999.508599           26      33     13.7
# 2016-11-28         63     61300    986.114191           32      31     11.1
# 2016-12-06         64     63050    988.828502           32      32     10.8
# 2016-09-28         64     62350    985.576923           22      42     26.5
# 2016-09-29         65     63750    987.500000           26      39     24.6
# 2016-11-15         66     66800   1018.515038           37      29     15.3
# 2016-10-19         67     65150    978.078704           25      42     20.8
# 2016-12-09         68     64100    954.559271           22      46     11.1
# 2016-11-18         70     68600    983.374690           32      38     11.3
# 2016-11-25         71     68350    967.005814           42      29      5.6
# 2016-11-04         71     68550    968.830645           34      37     14.0
# 2016-11-06         71     70400    991.549296           20      51     14.8
# 2016-10-06         72     71350   1000.000000           25      47     26.0
# 2016-11-09         72     70750    986.702128           29      43     10.4
# 2016-09-21         72     67850    948.809524           25      47     20.1
# 2016-10-27         73     70100    961.674347           14      59     19.0
# 2016-10-18         74     71950    988.155594           28      46     20.9
# 2016-12-07         74     71650    972.765152           48      26      7.5
# 2016-09-23         74     70650    957.224686           30      44     20.8
# 2016-12-12         75     74500   1000.000000           48      27      7.0
# ...               ...       ...           ...          ...     ...      ...
# 2016-11-29         85     82650    986.525974           45      40     10.5
# 2016-11-27         85     83800    959.988038           22      63     10.6
# 2016-09-19         86     86900   1013.354037           41      45     21.3
# 2016-11-02         86     81100    941.902072           31      55     10.9
# 2016-10-14         86     83900    988.164251           37      49     15.6
# 2016-10-25         87     86050   1006.851852           20      67     14.0
# 2016-10-20         87     87700   1009.000530           34      53     21.9
# 2016-10-21         88     86300    980.000000           28      60     18.2
# 2016-10-04         89     88800   1002.345388           31      58     24.9
# 2016-10-13         89     85450    962.044073           33      56     16.5
# 2016-11-07         90     86650    970.138889           31      59     11.0
# 2016-10-16         90     86200    956.384698           30      60     17.4
# 2016-12-08         91     89000    980.219512           56      35      8.6
# 2016-11-08         91     88700    978.851010           42      49      9.9
# 2016-11-03         91     87550    958.169399           33      58     12.9
# 2016-10-07         92     87900    970.208333           34      58     21.4
# 2016-11-30         92     91450    995.928571           48      44      8.8
# 2016-10-09         93     89700    973.598901           31      62     22.3
# 2016-11-11         94     91450    986.400894           42      52      9.0
# 2016-10-04     32.0     19.7         0.0       6.2        2.1        5.2
# 2016-10-13     18.2     15.3         0.0       0.0        2.7        4.7
# 2016-11-07     14.4      8.2         0.0       8.4        3.0        5.7
# 2016-10-16     22.9     12.7         0.0       5.2        1.9        3.8
# 2016-12-08     13.9      3.0         0.0       8.6        2.4        4.6
# 2016-11-08     13.6      6.1         2.0       1.8        1.8        3.9
# 2016-11-03     19.4      8.4         3.0       9.5        2.6        4.2
# 2016-10-07     24.9     19.0         0.0       5.8        3.6        7.2
# 2016-11-30     11.8      4.8         0.0       4.9        2.3        5.9
# 2016-10-09     25.7     18.6        32.5       0.0        3.9        8.2
# 2016-11-11     12.1      5.7        49.0       0.0        3.4        5.9
# 2016-11-20     20.4      8.9         0.0       6.9        1.4        3.0
# 2016-10-10     19.6     17.4         0.0       0.0        2.7        4.6
# 2016-10-26     25.7     12.6         0.0       9.6        1.7        3.5
# 2016-12-11     10.9      3.5         0.0       8.8        3.3        6.4
# 2016-11-23     14.7      8.5         0.0       0.1        2.8        5.9
# 2016-09-25     28.4     20.3         0.0       3.4        1.8        4.0
# 2016-10-24     19.1     11.9         0.0       9.8        2.4        4.3
# 2016-10-02     27.6     18.6         0.0       9.1        1.9        4.3
# 2016-10-30     13.5      9.6         1.0       0.0        2.3        4.7
# 2016-11-13     18.6      9.1         0.0       7.6        1.7        3.3
# 2016-10-23     22.3     14.7         0.0       4.8        2.4        5.0
#
#            最大風速(m/s).1  平均蒸気圧(hPa)  平均雲量(10分比) 天気概況(昼：06時〜18時)  \
# 日付
# 2016-12-02          北西         6.6         4.5          晴後一時薄曇
# 2016-12-05          北西        11.5         8.8           薄曇一時晴
# 2016-09-26          北東        28.0        10.0               曇
# 2016-10-11          北東        13.8        10.0               曇
# 2016-09-30         南南東        16.7        10.0               曇
# 2016-09-20          北西        22.1        10.0              大雨
# 2016-11-21          北東        12.8        10.0           曇後時々雨
# 2016-11-24          北西         6.7         9.5       みぞれ時々雪一時曇
# 2016-10-17         南南東        19.0        10.0             雨後曇
# 2016-11-10          北西         6.3         9.8               曇
# 2016-11-14          北西        13.5        10.0           曇後時々雨
# 2016-11-28         北北西         8.7         9.0           薄曇時々晴
# 2016-12-06          北西         7.7         2.8              快晴
# 2016-09-28          北西        29.6         8.5           曇後時々雨
# 2016-09-29          北東        27.0        10.0            曇時々雨
# 2016-11-15          北西        14.4        10.0               曇
# 2016-10-19         南南東        19.3         7.5            曇時々晴
# 2016-12-09          南西         7.3         1.5              快晴
# 2016-11-18           南         8.4         3.3           晴後一時曇
# 2016-11-25          南東         6.8         3.8           晴一時薄曇
# 2016-11-04          北西         8.2         2.0           晴後一時曇
# 2016-11-06         北北西         9.5         0.3              快晴
# 2016-10-06         南南西        19.9         7.5              薄曇
# 2016-11-09          北西         6.1         5.5            晴時々曇
# 2016-09-21          北東        20.2        10.0           曇後一時雨
# 2016-10-27         北北西        10.9         4.8            晴一時曇
# 2016-10-18          北東        21.2         9.8            晴時々曇
# 2016-12-07          北西         5.8         7.0            曇時々晴
# 2016-09-23          北西        24.6        10.0            雨一時曇
# 2016-12-12         西北西         4.8         5.3           薄曇時々晴
# ...                ...         ...         ...             ...
# 2016-10-25          曇一時雨後一時晴     1   月曜日
# 2016-10-20                 晴     3   月曜日
# 2016-10-21                 曇     4   月曜日
# 2016-10-04              曇時々晴     1   月曜日
# 2016-10-13                 曇     3   月曜日
# 2016-11-07                快晴     0   月曜日
# 2016-10-16              曇一時雨     6   月曜日
# 2016-12-08              晴時々曇     3   月曜日
# 2016-11-08              雨時々曇     1   月曜日
# 2016-11-03              晴一時曇     3   月曜日
# 2016-10-07                 曇     4   月曜日
# 2016-11-30               曇後雨     2   月曜日
# 2016-10-09                 曇     6   月曜日
# 2016-11-11              曇一時雨     4   月曜日
# 2016-11-20                薄曇     6   月曜日
# 2016-10-10                 曇     0   月曜日
# 2016-10-26           曇時々晴一時雨     2   月曜日
# 2016-12-11                快晴     6   月曜日
# 2016-11-23              曇時々雨     2   月曜日
# 2016-09-25                 曇     6   月曜日
# 2016-10-24                快晴     0   月曜日
# 2016-10-02              曇一時晴     6   月曜日
# 2016-10-30                 曇     6   月曜日
# 2016-11-13                 曇     6   月曜日
# 2016-10-23             曇後時々晴     6   月曜日
#
# [72 rows x 19 columns]

# %%
sns.jointplot('平均気温(℃)', '来客数 の SUM', data=rowdata, kind="scatter")

# %%
#散布図を書く
#sns.pairplot(data) #これだと散布図だけなので、PairGridする。
returns_fig = sns.PairGrid(data)
returns_fig.map_upper(plt.scatter, color='purple')
returns_fig.map_lower(sns.kdeplot, cmap='cool_d')
returns_fig.map_diag(plt.hist,bins=10)

# %%
#Group by で分析
week_group = rowdata[['リピート数 の SUM','新規のSUM']].groupby(rowdata['week'])
#week_group.mean()
week_group.mean().plot(legend=True, figsize=(16, 4), kind="bar", stacked=True)

#リピート数のweekごとの平均
#week_group['リピート数 の SUM'].mean()

#week0の数値 
#week_group.get_group(0)

# %%
#Pivot Table で分析 / aggfunc='mean' , columns='リピート数 の SUM'
rowdata.pivot_table(index="week",aggfunc='mean')
# Out:
#       リピート数 の SUM  単価 の AVERAGE      売上 の SUM    平均気温(℃)  平均蒸気圧(hPa)  \
# week
# 0       32.692308    981.563617  71830.769231  15.584615   14.584615
# 1       30.666667    979.930622  73225.000000  16.333333   15.366667
# 2       31.363636    973.303522  78150.000000  15.636364   14.009091
# 3       31.416667    983.835738  75200.000000  15.325000   13.025000
# 4       30.000000    967.931259  70279.166667  14.341667   11.450000
# 6       35.833333    988.442327  99066.666667  15.616667   13.858333
#
#       平均雲量(10分比)  平均風速(m/s)     新規のSUM  日照時間(時間)    最低気温(℃)  最大風速(m/s)  \
# week
# 0       8.392308   2.300000  40.846154  3.353846  12.769231   5.023077
# 1       7.916667   2.350000  44.500000  3.716667  13.191667   5.341667
# 2       7.936364   2.718182  49.272727  2.500000  12.681818   5.845455
# 3       7.108333   2.700000  45.250000  4.700000  11.691667   5.608333
# 4       6.508333   2.583333  42.916667  5.166667  10.700000   5.300000
# 6       6.958333   2.208333  64.000000  5.250000  11.816667   4.700000
#
#         最高気温(℃)  来客数 の SUM  降水量の合計(mm)
# week
# 0     18.876923  73.538462    5.000000
# 1     20.458333  75.166667    9.375000
# 2     19.009091  80.636364    0.636364
# 3     19.916667  76.666667    7.750000
# 4     18.141667  72.916667    7.166667
# 6     20.075000  99.833333    3.791667
