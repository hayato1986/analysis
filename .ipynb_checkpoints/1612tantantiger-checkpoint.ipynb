# %%
#必要なライブラリを予めすべてインポート
import pandas as pd
import numpy as np
import pylab as pl
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
# %matplotlib inline
sns.set_style('whitegrid')

# %%
#CSVデータをDF形式で読み込み。 indexにdateを設定
rowdata = pd.read_csv('./data/tantantigerdata.csv', 
                      parse_dates=['日付'],index_col=['日付'], dayfirst=True)
#rowdata['week'] = rowdata.index.weekday #曜日を追加してたけど元データで加工することにした

# %%
#データ概要1.
rowdata.sort_values(by='来客数', ascending=True).head(3)
# Out:
#              来客数     売上  単価平均  リピート数  新規数  平均気温  最高気温  最低気温   降水量  日照時間  平均風速  \
# 日付
#  9月 20 (火)    57  54300  1901     25   32  19.1  20.1  17.6  91.5   0.0   3.0
#  11月 21 (月)   57  55950  1981     29   28  12.6  14.7  10.2   2.5   0.0   2.3
#  10月 17 (月)   58  57450  1997     33   25  17.5  19.5  15.7  24.0   0.0   1.9
#
#              最大風速  風向き  蒸気圧(hPa)    天気昼   天気夜      曜日
# 日付
#  9月 20 (火)    6.2   北西      22.1     大雨  大雨後曇   2.火曜日
#  11月 21 (月)   4.5   北東      12.8  曇後時々雨  雨一時曇   1.月曜日
#  10月 17 (月)   5.9  南南東      19.0    雨後曇  曇時々雨   1.月曜日

# %%
#データ概要2
rowdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 77 entries,  9月 19 (月) to  12月 19 (月)
# Data columns (total 17 columns):
# 来客数         77 non-null int64
# 売上          77 non-null int64
# 単価平均        77 non-null int64
# リピート数       77 non-null int64
# 新規数         77 non-null int64
# 平均気温        77 non-null float64
# 最高気温        77 non-null float64
# 最低気温        77 non-null float64
# 降水量         77 non-null float64
# 日照時間        77 non-null float64
# 平均風速        77 non-null float64
# 最大風速        77 non-null float64
# 風向き         77 non-null object
# 蒸気圧(hPa)    77 non-null float64
# 天気昼         77 non-null object
# 天気夜         77 non-null object
# 曜日          77 non-null object
# dtypes: float64(8), int64(5), object(4)
# memory usage: 10.8+ KB

# %%
#データ概要3
rowdata.describe().astype(int)
# Out:
#        来客数      売上  単価平均  リピート数  新規数  平均気温  最高気温  最低気温  降水量  日照時間  平均風速  最大風速  \
# count   77      77    77     77   77    77    77    77   77    77    77    77
# mean    82   81094   981     33   49    14    18    11    5     4     2     5
# std     15   16141    18      9   16     5     5     6   14     3     0     1
# min     57   54300   942     14   23     2     8     0    0     0     1     3
# 25%     72   70100   970     26   37    10    14     7    0     0     1     4
# 50%     82   81050   980     33   49    13    18    10    0     3     2     4
# 75%     91   88700   995     41   60    19    22    17    2     7     3     6
# max    128  126450  1027     56   94    26    32    24   91    10     4    10
#
#        蒸気圧(hPa)
# count        77
# mean         13
# std           6
# min           3
# 25%           7
# 50%          11
# 75%          18
# max          29

# %% [markdown]
# ***
# # タンタンタイガーの下半期売上分析
# ## Objective(目的)＆Why (なぜやるのか)
# タンタンタイガーの下半期売上データに対する分析をする。
# 各データから意味を抽出して、売上に影響している要因を見つけ出し、改善アクションにつなげることを目的とする。
#
# ## Data for deep dive (見てみるデータ)
# 1. 時系列における売上の推移はどうなっているか
#  - 開店直後からの数値推移
#  - 新規顧客の推移
#  - リピーターの推移
#  - リピーターと曜日の相関
# 2. 天候による売上の相関関係はどうなっているか
#  - 気温と売上の相関
#  - 天気と売上の相関
# 3. 売上の回帰モデルはどうなっているか
#  - 重回帰式の作成と妥当性の検証

# %%
#1. 時系列における売上の推移はどうなっているか
#rowdata['売上'].plot(legend=True, figsize=(16, 4))

fig, axes = plt.subplots(nrows=5, ncols=1, figsize=(16,12),  squeeze=False) #squeezeはsubplotsのおまじない

#i=0
for i, col in enumerate(rowdata):
    rowdata[col].plot(ax=axes[i,0])
    axes[i,0].set_title(col, fontsize=14, fontweight='bold')
    i+=1
    if i == 5:
        break
plt.tight_layout() #スペース調整
# Out:
# 0:来客数
# 1:売上
# 2:単価平均
# 3:リピート数
# 4:新規数

# %%
#よくわからないので移動平均的で出す。
rowdata_rolling = rowdata.rolling(window=8, min_periods=8).mean() #8日の移動平均
fig, axes = plt.subplots(nrows=5, ncols=1, figsize=(16,12),  squeeze=False) #squeezeはsubplotsのおまじない

i=0
for col in rowdata_rolling:
    rowdata_rolling[col].plot(ax=axes[i,0])
    axes[i,0].set_title(col, fontsize=14, fontweight='bold')
    i+=1
    if i == 5:
        break
plt.tight_layout()

# %%
rowdata_rolling.loc[:,['リピート数','新規合計']].plot(
    legend=True, figsize=(16, 8), y=['リピート数','新規合計']
          , kind='area', stacked=True, alpha=0.5
)

# %% [markdown]
# - リピーター数は伸びている
# - 新規は10月22日のTVCMで大きく増えたが少し右肩下がり
# - リピーター数が伸びているので新規の落ち込みをカバーしている。全体では減ってない

# %% [markdown]
# # 2. 天候による売上の相関関係はどうなっているか

# %%
#とりあえず変数すべてで相関のヒートマップを見てみよう
fig, ax = plt.subplots(figsize=(20,20)) #Sizeを定義する
sns.heatmap(rowdata.corr() ,annot=True, linewidths=.5, ax=ax)

# %%
#よくわからないので相関がないところを削除していく。
fig, ax = plt.subplots(figsize=(10,10)) #Sizeを定義する
data = rowdata.drop(['最高気温','最低気温','日照時間', '平均風速(m/s)', '最大風速(m/s)','平均気温', '平均蒸気圧(hPa)'], axis=1)
sns.heatmap(data.corr() ,annot=True, linewidths=.5, ax=ax)

# %% [markdown]
# - リピート数と単価平均に相関が見られそう
# - 平均気温とリピート数に負の相関があるかも。逆に新規には正の相関？
# - 雨と来店数はあんまり関係なさそう
# - 風はすべての数値にほとんど関係ない
# - 来客数は新規の数で決まることが多そう

# %%
#気温と売上の相関を詳しく見てみる　=> 来客数 の SUMと平均気温(℃)
#sns.jointplot('平均気温(℃)', '来客数 の SUM', data=rowdata, kind="scatter")
rowdata.sort_values(by='来客数', ascending=True)
# Out:
#              来客数      売上  単価平均  リピート数  新規合計  平均気温  最高気温  最低気温  降水量(mm)  日照時間  \
# 日付
#  9月 20 (火)    57   54300  1901     25    32  19.1  20.1  17.6     91.5   0.0
#  11月 21 (月)   57   55950  1981     29    28  12.6  14.7  10.2      2.5   0.0
#  10月 17 (月)   58   57450  1997     33    25  17.5  19.5  15.7     24.0   0.0
#  11月 24 (木)   58   56600  1946     28    30   2.8   8.6   0.9     23.0   0.0
#  11月 10 (木)   59   57350  1952     35    24   9.6  13.0   7.6      0.0   0.5
#  11月 14 (月)   59   58350  1999     26    33  13.7  16.7  11.5      6.0   0.0
#  11月 28 (月)   63   61300  1972     32    31  11.1  14.0   9.4      7.5   3.3
#  9月 28 (水)    64   62350  1971     22    42  26.5  30.6  24.0      0.0   2.1
#  12月 6 (火)    64   63050  1978     32    32  10.8  17.1   7.0      0.0   8.5
#  9月 29 (木)    65   63750  1975     26    39  24.6  27.9  21.7      0.0   0.7
#  11月 15 (火)   66   66800  2037     37    29  15.3  19.3  12.7      0.0   1.6
#  10月 25 (火)  曇一時雨後一時晴   火曜日
#  10月 20 (木)         晴   木曜日
#  10月 21 (金)         曇   金曜日
#  10月 13 (木)         曇   木曜日
#  10月 4 (火)       曇時々晴   火曜日
#  11月 7 (月)         快晴   月曜日
#  10月 16 (日)      曇一時雨   日曜日
#  11月 8 (火)       雨時々曇   火曜日
#  12月 8 (木)       晴時々曇   木曜日
#  11月 3 (木)       晴一時曇   木曜日
#  11月 30 (水)       曇後雨   水曜日
#  10月 7 (金)          曇   金曜日
#  10月 9 (日)          曇   日曜日
#  11月 11 (金)      曇一時雨   金曜日
#  11月 20 (日)        薄曇   日曜日
#  10月 10 (月)         曇   月曜日
#  10月 26 (水)   曇時々晴一時雨   水曜日
#  12月 11 (日)        快晴   日曜日
#  12月 18 (日)     薄曇時々晴   日曜日
#  11月 23 (水)      曇時々雨   水曜日
#  9月 25 (日)          曇   日曜日
#  10月 24 (月)        快晴   月曜日
#  11月 6 (日)        晴後曇   日曜日
#  10月 2 (日)       曇一時晴   日曜日
#  12月 4 (日)       雨時々曇   日曜日
#  10月 30 (日)         曇   日曜日
#  11月 13 (日)         曇   日曜日
#  10月 23 (日)     曇後時々晴   日曜日
#
# [77 rows x 17 columns]

# %%
sns.jointplot('平均気温(℃)', '来客数 の SUM', data=rowdata, kind="scatter")

# %%
#散布図を書く
#sns.pairplot(data) #これだと散布図だけなので、PairGridする。
returns_fig = sns.PairGrid(data)
returns_fig.map_upper(plt.scatter, color='purple')
returns_fig.map_lower(sns.kdeplot, cmap='cool_d')
returns_fig.map_diag(plt.hist,bins=10)

# %%
#Group by で分析
week_group = rowdata[['リピート数','新規合計']].groupby(rowdata['曜日'])
#week_group.mean()
week_group.mean().plot(legend=True, figsize=(16, 4), kind="bar", stacked=True)

#リピート数のweekごとの平均
#week_group['リピート数 の SUM'].mean()

#week0の数値 
#week_group.get_group(0)

# %%
#Pivot Table で分析 / aggfunc='mean' , columns='リピート数 の SUM'
rowdata.pivot_table(index="曜日",aggfunc='mean')
# Out:
#           リピート数         単価平均             売上       平均気温  平均蒸気圧(hPa)  平均風速(m/s)  \
# 曜日
#  日曜日  36.769231  1970.076923  104880.769231  15.046154   13.284615   2.161538
#  月曜日  32.928571  1974.071429   76667.857143  15.185714   14.042857   2.242857
#  木曜日  32.307692  1969.230769   75207.692308  14.623077   12.315385   2.730769
#  水曜日  32.416667  1942.916667   77220.833333  15.008333   13.516667   2.758333
#  火曜日  34.166667  1969.416667   75904.166667  15.650000   14.866667   2.325000
#  金曜日  31.692308  1946.000000   76330.769231  13.607692   10.869231   2.653846
#
#            新規合計      日照時間       最低気温  最大風速(m/s)       最高気温         来客数  \
# 曜日
#  日曜日  69.230769  5.430769  11.153846   4.630769  19.676923  106.000000
#  月曜日  45.285714  3.707143  12.192857   4.885714  18.650000   78.214286
#  木曜日  44.307692  4.869231  11.030769   5.646154  19.161538   76.615385
#  水曜日  47.416667  2.316667  12.066667   5.891667  18.366667   79.833333
#  火曜日  43.500000  3.908333  12.125000   5.325000  20.058333   77.666667
#  金曜日  47.230769  5.430769   9.992308   5.461538  17.500000   78.923077
#
#        降水量(mm)
# 曜日
#  日曜日  3.500000
#  月曜日  4.642857
#  木曜日  7.153846
#  水曜日  3.666667
#  火曜日  9.625000
#  金曜日  6.615385
